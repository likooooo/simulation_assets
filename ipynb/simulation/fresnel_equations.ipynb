# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import sys
import os
BUILD = os.environ["SIMULATION_ARTIFACTS_DIR"]  # noqa: F401
import simulation
from simulation import test_fresnel
test_fresnel("glass_to_air")
# Out:
# * fresnel equations(glass to air)
#     brewster's angle = 33.6364° at Rp_power = 1.59785e-06
#     brewster's angle(analytic solution) = 33.6901°
#     total internal reflection = 41.8182° at Rp_power = 1
# ---> test success. fresnel equations(glass to air)
# 图像已保存至: /tmp/simulation_plot_data_062623/231950_834233_Curves.png
# 图像已保存至: /tmp/simulation_plot_data_062623/231950_943475_Curves.png

# %% [markdown]
# - golden result from wiki
#
# ![Fresnel_power_glass-to-air](resource/Fresnel_power_glass-to-air.svg)
# ![Fresnel_amplitudes_glass-to-air](resource/Fresnel_amplitudes_glass-to-air.svg)

# %%
test_fresnel("air_to_glass")
# Out:
# * fresnel equations(air to glass)
#     brewster's angle = 56.3636° at Rp_power = 3.19025e-07
#     brewster's angle(analytic solution) = 56.3099°
#     total internal reflection = 90° at Rp_power = 1
# 图像已保存至: /tmp/simulation_plot_data_062623/231951_073786_Curves.png
# 图像已保存至: /tmp/simulation_plot_data_062623/231951_227560_Curves.png
# ---> test success. fresnel equations(air to glass)

# %% [markdown]
# - golden result from wiki
#
# ![Fresnel_power_air-to-glass](resource/Fresnel_power_air-to-glass.svg)
# ![Fresnel_amplitudes_air-to-glass](resource/Fresnel_amplitudes_air-to-glass.svg)

# %% [markdown]
# - reference:
# [Fresnel_equations wiki](https://en.wikipedia.org/wiki/Fresnel_equations)
