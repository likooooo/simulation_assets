# %%
import os
os.system("./test_sturm_liouville_benchmark_matlab_pde_suite.sh --N 128 256 -L 1 2 --BC 1 2 2 1 -m 2 3  8 9")
# Out:
# ����: ���Ʋ����ڻ���Ŀ¼: C:\Users\like\Desktop\EasyPPI
#
# ...
# N          : 128 256
# L          : 1 2
# BC         : 1 2 2 1
# MODE       : 2 3 8 9
# Shape      : 128 256
# VISUALIZE  : false
# ...
#
# ...
# MATLAB PDE Benchmark
# ...
# Max Error : 1.975887e-01
# L2 Error  : 2.229864e-02
# Rel Error : 3.153514e-02
# ...
#
# Saved MAT:
#   benchmark_poisson_equation.mat
#
# ...
# Figure saved to:
# C:\Users\like\AppData\Local\Temp\tpaa73f070_c582_4b10_842f_efa5b6059ded.png
# ...
# ����: �޷���� \\wsl.localhost\ubuntu\home\like\repos\simulation\build �ĸ���֪ͨ�����
# real	0m21.045s
# user	0m0.001s
# sys	0m0.001s
# [16:08:01] Error: 管道中没有数据。
# [16:08:01] load data from ./benchmark_poisson_equation.mat success
# [16:08:01] send spectrum success
# [16:08:01]
# [16:08:01] =====================================
# [16:08:01] Python Solver Benchmark
# [16:08:01] =====================================
# [16:08:01] Max Error : 4.218847e-15
# [16:08:01] L2 Error  : 6.904341e-16+0.000000e+00j
# [16:08:01] Rel Error : 9.764241e-16
# ...

# %% [markdown]
# #### matlab results
#
# - poisson equation
#
# ![baseline of poisson equation](/home/like/repos/simulation_assets/ipynb/simulation/sturm_liouville/resource/tpaa73f070_c582_4b10_842f_efa5b6059ded.png)
#
# - laplace operator
#
# ![baseline of laplace operator](/home/like/repos/simulation_assets/ipynb/simulation/sturm_liouville/resource/tpb0caa049_7d05_4260_8383_018cd64c0035.png)

# %% [markdown]
# sturm liouville solver results
#
#
# - poisson equation
#
# ![baseline of poisson equation](/home/like/repos/simulation_assets/ipynb/simulation/sturm_liouville/resource/SL-1.png)
#
# - laplace operator
#
# ![baseline of laplace operator](/home/like/repos/simulation_assets/ipynb/simulation/sturm_liouville/resource/SL-2.png)
