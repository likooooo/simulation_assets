# %% [markdown]
# #### Kirchhoff Approximation
#
# the object in an optical system is modeled as an infinitely thin film with a complex transmission function T(x,y).
#
# $$
# E_x'(x,y) = T(x,y) \cdot E_x(x,y) \\
# E_y'(x,y) = T(x,y) \cdot E_y(x,y) \\
# E_z'(x,y) = T(x,y) \cdot E_z(x,y)
# $$
#
# ---
#
# - kirchhoff approximation 支持两种传递函数的构建, 分别是 binary_mask 和 thin_mask.
# - 他们二者在整网格点时结果完全一致. (参考下面 cd = 8 的结果)
# - thin_mask 目前不支持 1d, 在 2d 复杂图形时有更快的速度(待详细测试)
# - thin_mask 支持 sub-pixel 精度
# - 请注意，几何图形的单位是 物理尺寸/dbu

# %%
# %matplotlib inline
from simulation import *
from math import *
import numpy as np
import visualizer

wavelength = 13.0
NA = 0.9
pitch = 16
dx = 1
size = int(ceil(pitch / dx))
grid_info_2d = grid_info_2d_s.create(
    [size, size],
    [[pitch, 0], [0, pitch]],
    ["periodic", "periodic"],
    ["periodic", "periodic"],
    [-pitch/2, -pitch/2],
)
print(grid_info_2d)

background = 0 + 0j
absorber = 1 + 0j
for cd in [7, 8, 9]:
    print(f"* cd={cd}")
    layer = layer_s()
    layer.background_material = share_material_s(material_s.from_epsilon(background, "bg"))
    layer.shapes = [
        make_rect_shape_s([cd / 2, cd / 2], [0, 0], 0, share_material_s(material_s.from_epsilon(absorber, "fg")))
    ]
    layer.parent = [-1]

    binary = raster_layer_binary_mask_s(layer, grid_info_2d, wavelength)
    thin = raster_layer_thin_mask_s(layer, grid_info_2d, wavelength)
    visualizer.display_complex_field(np.array(binary).reshape((size, size)), f"binary cd={cd}")
    visualizer.display_complex_field(np.array(thin).reshape((size, size)), f"thin cd={cd}")

# %%
print("1d 示例已迁移到 2d 物理网格接口，建议直接使用上面的 2d raster 结果")

# %%
# thin_mask 仅支持 Manhattan 2d shape；1d 例子不再维护
