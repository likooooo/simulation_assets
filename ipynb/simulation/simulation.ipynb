# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('/home/like/repo/simulation/build')
from lib_test_simulation import *

simulation("/home/like/repos/simulation/config/calib_193.py")
# Out:
# verbose  dbu      layer_id  cell_name  oas_file                                                                gauge_file                                                    ambit  tilesize  maxSigma  maxNA  wavelength
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 0        0.00025  300       JDV_M      /home/like/model_data/X_File/LG40_.../LG40_PC_CDU_Contour_Mask_L300.oas  /home/like/model_data/X_File/LG40_poly_File/LG40_PC_CDU_7.ss  [0,0]  [8,8]     0         1.2    0.193
#     grid-um
# * optical numerics with tilesize=[8,8]
# -----------------------------------------------------------------
# spatial start :                         [2311.34,21769.3]
# spatial step  :                         [0.0402083,0.0402083]
# fourier start :                         [0,0]
# fourier step  :                         [0.6,0.6]
#     grid-dbu to grid-um
# * optical numerics with tilesize=[8,8]
# ---------------------------------------------------------------
# spatial start :                         [2311.34,21769.3]
# spatial step  :                         [0.04,0.04]
# fourier start :                         [0,0]
# fourier step  :                         [0.603125,0.603125]
#     load gauge file success
#     subclip workdir is /tmp/simulation/LG40_PC_CDU_Contour_Mask_L300
# 开始处理 7 个裁剪区域...
#     已保存: /tmp/simulation/LG40_PC_CDU_Contour_Mask_L300/0.oas
#     已保存: /tmp/simulation/LG40_PC_CDU_Contour_Mask_L300/1.oas
#     已保存: /tmp/simulation/LG40_PC_CDU_Contour_Mask_L300/2.oas
#     已保存: /tmp/simulation/LG40_PC_CDU_Contour_Mask_L300/3.oas
#     已保存: /tmp/simulation/LG40_PC_CDU_Contour_Mask_L300/4.oas
#     已保存: /tmp/simulation/LG40_PC_CDU_Contour_Mask_L300/5.oas
#     已保存: /tmp/simulation/LG40_PC_CDU_Contour_Mask_L300/6.oas
# 处理完成！
#     subclip success
#     verbose of 0.oas
# clip_dir, job-count = (/tmp/simulation/LG40_PC_CDU_Contour_Mask_L300, 7)
# center=[2311.5,21769.5]

# %%
print(wavelength)
# Out:
# 0.193
