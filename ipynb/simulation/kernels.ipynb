# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('/home/like/repos/infrastructure/kernels/build/tests')
from lib_test_bloch import *
xsize = ysize =128
freq  = 1
crao  = 0.5 * 3.1415926
azimuth = 0.25 * 3.1415926
test_bloch(xsize, ysize, freq, crao, azimuth)
# Out:
# * bloch test with (shape, lambda, crao(PI), azimuth(PI))=([128,128], 1, 0.5, 0.25)
#     realpart of bloch phase
#     imagpart of bloch phase
#     phase modulate with shift [0.707107,0.707107](pixel)
#     realpart of phase modulate
#     imagpart of phase modulate
#     error image. max error = 1.59139

# %%
auto_test_bloch()
