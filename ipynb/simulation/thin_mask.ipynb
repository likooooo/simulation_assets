# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('/home/like/repo/simulation/build')
from lib_test_simulation import *

# %%
s = thin_mask_simulation() 
s.load_user_config("/home/like/repos/simulation/config/calib_193.py", True)
cutline_debug_list = list(range(0, 32))
threshold_guess = 0.5
gauge_file = "/home/like/model_data/X_File/LG40_poly_File/LG40_PC_CDU_thin_mask_test.ss"
# Out:
# verbose  dbu      layer_id  cell_name  oas_file                                                                gauge_file                                                    ambit          tilesize  maxSigma  maxNA  wavelength
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# -1       0.00025  300       JDV_M      /home/like/model_data/X_File/LG40_.../LG40_PC_CDU_Contour_Mask_L300.oas  /home/like/model_data/X_File/LG40_poly_File/LG40_PC_CDU_7.ss  [0.193,0.193]  [64,64]   0         1.2    0.193

# %%
s.load_gauge_file(False)
for g in s.gauge_table:
    g.weight = 1
    g.measured_cd = g.desigin_cd
# Out:
# use design cd for test

# %%
s.clip_cutline(True)
# Out:
#     subclip workdir is /tmp/simulation/LG40_PC_CDU_Contour_Mask_L300
# *     simulation domain(um)  grid_start_step<double, 2ul>
# -------------------------------------------------------------
# tilesize      :              [64,64]
# spatial start :              [-1.27975,-1.27975]
# spatial step  :              [0.04,0.04]
# fourier start :              [0,0]
# fourier step  :              [0.0753906,0.0753906]
#     subclip alread done

# %%
s.gather_cutline_and_features(False)

# %%
s.calib_optical_threshold(True)
# Out:
# weight is 1
# weight is 1
# weight is 1
# weight is 1
# weight is 1
# weight is 1
# weight is 1
# pattern-name  cutline(dbu)                             polar  design-cd(dbu)  measured-cd(dbu)  weight  post-calib-results
# -------------------------------------------------------------------------------------------------------------------------------------
# L48P110       [[9245770,87078000],[9246230,87078000]]  1      192             192               1       [192.209,0.0523434]
# L48P114       [[9309791,87078000],[9310209,87078000]]  1      192             192               1       [191.605,-0.0988018]
# L48P116       [[9341797,87078000],[9342203,87078000]]  1      192             192               1       [191.892,-0.0270045]
# L48P118       [[9373804,87078000],[9374196,87078000]]  1      192             192               1       [193.483,0.370657]
# L48P122       [[9437808,87078000],[9438192,87078000]]  1      192             192               1       [193.063,0.265721]
# L48P126       [[9501808,87078000],[9502192,87078000]]  1      192             192               1       [193.063,0.265721]
# L48P130       [[9565808,87078000],[9566192,87078000]]  1      192             192               1       [193.063,0.265721]
#     post-calib-results are [simulated-cd(dbu) , error(nm)]
#     optical threshold is 0.499657
