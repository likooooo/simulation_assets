# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('/home/like/repo/simulation/build')
from lib_test_zernike import *
size = 100

# %% [markdown]
# ![zernike mode map](https://www.minamiaoyama.or.jp/blog/wp-content/uploads/2014/06/zernike.png)

# %%
mnf = [
    [0,0, 1],
    [1, 0, -1], [1, 0, 1], 
    [2, 0, -1], [0, 1, 1], [2, 0, 1], 
    [3, 0, -1], [1, 1, -1], [1, 1, 1], [3, 0, 1], 
    [4, 0, -1], [2, 1, -1], [0, 2, 1],[2, 1, 1], [4, 0, 1], 
    [5, 0, -1], [3, 1, -1], [1, 2, -1], [1, 2, 1], [3, 1, 1], [5, 0, 1], 
    [6, 0, -1], [4, 1, -1], [2, 2, -1], [0, 3, 1], [2, 2, 1], [4, 1, 1], [6, 0, 1], 
]
# display_zernike_image(0, 2, size, 1)
# display_zernike_image(0, 4, size, 1)
# f 的 +-1分别代表 cos(m\theta), sin(m\theta)
for m,n,f in mnf:
    display_zernike_image(m, n, size, f)
# Out:
# Z(m,l)=[0,0]
#     [1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421,1.41421]
# Z(m,l)=[1,0]
#     [0,0.0408163,0.0816327,0.122449,0.163265,0.204082,0.244898,0.285714,0.326531,0.367347,0.408163,0.44898,0.489796,0.530612,0.571429,0.612245,0.653061,0.693878,0.734694,0.77551,0.816327,0.857143,0.897959,0.938776,0.979592,1.02041,1.06122,1.10204,1.14286,1.18367,1.22449,1.26531,1.30612,1.34694,1.38776,1.42857,1.46939,1.5102,1.55102,1.59184,1.63265,1.67347,1.71429,1.7551,1.79592,1.83673,1.87755,1.91837,1.95918,2]
# Z(m,l)=[1,0]
# ...
