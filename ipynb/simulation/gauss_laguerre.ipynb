# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('/home/like/repos/infrastructure/kernels/build/tests')
from lib_test_gauss_laguerre import *
xsize = ysize =128
sigma = 128 * 0.1

for laguerre_order in range(0, 2):
    for associated_order in range(0, 1):
        print(f"laguerre={laguerre_order},  associate={associated_order}")
        gauss_laguerre(xsize, ysize, sigma, laguerre_order, associated_order)
# Out:
# laguerre=0,  associate=0
# laguerre=0,  associate=1
# laguerre=0,  associate=2
# laguerre=1,  associate=0
# laguerre=1,  associate=1
# laguerre=1,  associate=2
# laguerre=2,  associate=0
# laguerre=2,  associate=1
# laguerre=2,  associate=2
# laguerre=3,  associate=0
# laguerre=3,  associate=1
# laguerre=3,  associate=2
