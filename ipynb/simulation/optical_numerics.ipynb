# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import os
import sys
sys.path.append('/home/like/repo/simulation/build')
from lib_test_optical import *

for wave_length in [248, 193, 13.5]:
    optical_numerics_test([[0.0, -200.0], [400.0, 200.0]], [0.0, 0.0], [160, 160],0.5, 0, wave_length)
# Out:
# * OPC mode
# * optical numerics with tilesize=[160,160]
# ---------------------------------------------------------------
# spatial start :                             [-9720,-9920]
# spatial step  :                             [124,124]
# fourier start :                             [0,0]
# fourier step  :                             [0.0125,0.0125]
# * Bloch mode
# * optical numerics with tilesize=[160,160]
# -----------------------------------------------------------
# spatial start :                             [0,-200]
# spatial step  :                             [2.5,2.5]
# fourier start :                             [0,0]
# fourier step  :                             [0.62,0.62]
#
# * OPC mode
# * optical numerics with tilesize=[160,160]
# ---------------------------------------------------------------
# spatial start :                             [-7520,-7720]
# spatial step  :                             [96.5,96.5]
# fourier start :                             [0,0]
# fourier step  :                             [0.0125,0.0125]
# * Bloch mode
# * optical numerics with tilesize=[160,160]
# ---------------------------------------------------------------
# spatial start :                             [0,-200]
# spatial step  :                             [2.5,2.5]
# fourier start :                             [0,0]
# fourier step  :                             [0.4825,0.4825]
#
# * OPC mode
# * optical numerics with tilesize=[160,160]
# ---------------------------------------------------------------
# spatial start :                             [-340,-540]
# spatial step  :                             [6.75,6.75]
# fourier start :                             [0,0]
# fourier step  :                             [0.0125,0.0125]
# * Bloch mode
# * optical numerics with tilesize=[160,160]
# -----------------------------------------------------------------
# spatial start :                             [0,-200]
# spatial step  :                             [2.5,2.5]
# fourier start :                             [0,0]
# fourier step  :                             [0.03375,0.03375]
