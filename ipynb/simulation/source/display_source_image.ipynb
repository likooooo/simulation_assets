# %%
# %matplotlib inline
from simulation import *

source_type = ["traditional", "annular", "dipole_fan", "dipole_fan1", "quadratic_fan", "quadratic_fan1", "dipole_leaf", "quadratic_leaf", "quadratic_leaf1", "quadratic_leaf2"]
shape = [128, 128]
for t in source_type:
    for sigma in [0.1, 0.5, 0.9]:
        print(f"* source type = {t}. shape={shape} sigma={sigma}")
        display_source_image(t, shape, sigma)
# Out:
# * source type = traditional. shape=[128, 128] sigma=0.1
# * source type = traditional. shape=[128, 128] sigma=0.5
# * source type = traditional. shape=[128, 128] sigma=0.9
# * source type = annular. shape=[128, 128] sigma=0.1
# * source type = annular. shape=[128, 128] sigma=0.5
# * source type = annular. shape=[128, 128] sigma=0.9
# * source type = dipole_fan. shape=[128, 128] sigma=0.1
# * source type = dipole_fan. shape=[128, 128] sigma=0.5
# * source type = dipole_fan. shape=[128, 128] sigma=0.9
# * source type = dipole_fan1. shape=[128, 128] sigma=0.1
# * source type = dipole_fan1. shape=[128, 128] sigma=0.5
# * source type = dipole_fan1. shape=[128, 128] sigma=0.9
# * source type = quadratic_fan. shape=[128, 128] sigma=0.1
# * source type = quadratic_fan. shape=[128, 128] sigma=0.5
# * source type = quadratic_fan. shape=[128, 128] sigma=0.9
# * source type = quadratic_fan1. shape=[128, 128] sigma=0.1
# * source type = quadratic_fan1. shape=[128, 128] sigma=0.5
# ...
